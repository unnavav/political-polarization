# %% [markdown]
# # Getting Steady State
#
# ## intro
# This code implements the steady state solution for various political regimes. Some things to note:
#
# - Each steady state is "regime-specific," which means that individuals are not considering other regimes or even the possibilty of transitioning to another regime
# - This is all in Julia, and I'm falling apart trying to code it
# -
#
# To run this code, simply click "Run." I think, honestly this is for replicability but I always assumed Jupyter was for suckers until I realized this is 10x better than my "self-documenting code."
#
# ## directory structure
#
# I grew up oop-ing, so this is a result of that. All my functions are stored in the relevant module.
#
# ```
# populism/
# ├── src/                        # your modules
# │   ├── ModelTypes.jl
# │   ├── ModelFunctions.jl
# │   ├── Compute.jl
# │   ├── EGM.jl
# │   ├── DistTools.jl
# │   └── Solvers.jl
# ├── PopulismModel.jl            # parent module, includes everything
# ├── notebooks/
# │   └── figures.ipynb           # if you want plots separate
# └── Utitled.ipynb              # primary replication notebook, this one, for now.
# ```
#
# Running `PopulismModel.jl` imports all the necessary functions, and `ModelTypes.jl` defines the structres that I'll be passing in between functions.
#
# ## running
#
# Importing all the necessary methods below.

# %%
# run if you don't have this package (I didn't), otherwise comment out
# import Pkg; Pkg.add("Printf"); Pkg.add("JLD2")
using JLD2

using Printf
using LinearAlgebra: dot

include("src/ModelTypes.jl")
@printf("Loaded ModelTypes.jl\n")

include("src/Compute.jl")
@printf("Loaded Compute.jl\n")

include("src/ModelFunctions.jl")
@printf("Loaded ModelFunctions.jl\n")

include("src/EGM.jl")
@printf("Loaded EGM.jl\n")

include("src/DistrTools.jl")
@printf("Loaded DistrTools.jl\n")

include("src/Solvers.jl")
@printf("Loaded Solvers.jl\n")

include("src/SteadyState.jl")
@printf("Loaded Steady States.jl\n")

using .ModelTypes
using .ModelFunctions
using .Compute
using .EGM
using .DistrTools
using .Solvers
using .SteadyState
# Out:
# Loaded ModelTypes.jl
# Loaded Compute.jl
# Loaded ModelFunctions.jl
# Loaded EGM.jl
# Loaded DistrTools.jl
# Loaded Solvers.jl
# Loaded Steady States.jl

# %% [markdown]
# Putting in the calibrations that I'll throw through

# %%
# model parameters
const α::Float64 = 0.36;
const β::Float64 = 0.96;
const δ::Float64 = 0.06;
const σ::Float64 = 2;
const ϕ::Float64 = 0;

# grid sizes and parameters
const na::Int64 = 100; 
const nl::Int64 = 7;
const nz::Int64 = 2;

const a_l::Float64 = 0;
const a_h::Float64 = 100;

# calibrations for idiosyncratic income (vibes)
const μ_l::Float64 = 0; 
const ρ_l::Float64 = .9;
const σ_l::Float64 = .2;

# calibrations for aggregate TFP (Khan and Thomas 2013 would have 
# ρ_z = 0.909; I am setting it lower for two dimensional z with
# some variance for now.)
const μ_z::Float64 = 0;
const ρ_z::Float64 = .75;
const σ_z::Float64 = 0.014;

# %% [markdown]
# Now getting the transition matrices for idiosyncratic productivity ($\varepsilon$) and aggregate TFP ($z$). We'll also construct the savings grid, which is logspaced.

# %%
# need to back out σ^2_e given σ^2_l
σ_le = σ_l*sqrt(1 - ρ_l^2);
grid_range = 2.575;

π_l, lgrid = getTauchen(nl,  μ_l, σ_le, ρ_l, grid_range);

stationary_l = stationary(π_l);
const lagg::Float64 = dot(stationary_l, lgrid);

σ_ze = σ_z*sqrt(1 - ρ_z^2);
π_z, zgrid= getTauchen(nz,  μ_z, σ_ze, ρ_z, grid_range);

agrid = logspace(a_l, a_h, na);
amu = collect(range(a_l, a_h, length=na*10));

# %% [markdown]
# Now that we have all the grids, we can initiate the model params into a single object I can pass into the steady state process:

# %%
const params = ModelParams(α, β, δ, σ, ϕ, agrid, 
    lgrid, zgrid, π_l, π_z, amu);

# %% [markdown]
# Now we move on to defining the government problem. Because we want this to be solving a ton of steady states across various combinations of regime policies, what I'm going to do is linearly space out the policies:
# - $\tau$: no progressivity (0) to fully redistributive (1);
# - $\eta$: no immigration (0) to full addition of population in the next year (1).
#
# Then we'll loop through these regime combinations and solve for the steady state in each combination.

# %%
const np::Int64 = 10; # number of policies
const pol_l::Float64 = 0;
const pol_h::Float64 = 1;

τ_grid = range(pol_l, pol_h, length = np);
η_grid = range(pol_l, pol_h, length = np);

captax = repeat([0], outer = 7);

# %% [markdown]
# It's now time to loop (I hope). I'm going to, for each policy combination, solve for steady state by:
# 1. Making a guess at the aggregate capital demanded on the market (`K_val`)
# 2. Calculate the implied interest rate (`r`) and wages (`w`) given aggregate labor (`lagg`) multiplied by the policy coefficient for migrants (`\eta`).
# 3. Check, after solving the HH problem, how much capital would be supplied at this rate.
# 4. If it's off, adjust guess by a binary search between new bounds and try again.

# %%
# I need to initialize these variables outside the loop or Julia just doesn't save them? 
# Because apparently it constructs local variables _inside_ a loop, like it's on drugs.
# Something, something, speed. 
V = nothing
G = nothing  
C = nothing
CI = nothing
LI = nothing
μ = nothing
results = Dict{Tuple{Float64,Float64}, NamedTuple}()

kl::Float64 = 0; kh::Float64 = 20; 
kval::Float64 = (kl + kh)/2;

kdist::Float64 = 1e5

vTol::Float64 = 1e-6
kTol::Float64 = 1e-4

for η in η_grid
    for τ in τ_grid
 
        policies = ProposedPolicies(η, τ, captax)
        
        kl = 0.0
        kh = 20.0
        kval = 0.5 * (kl + kh)
        kdist = 1e5
        
        @printf("Solving (eta, tau) = (%4.2f, %4.2f)--------------\n", η, τ)
        
        while kdist > kTol
    
            @printf("\n\nK guess: %4.8f\n", kval)
            
            V, G, C, CI, LI = solveHousehold(params, policies, kval, vTol);

            μ, K = getDistr(G, amu, agrid, π_l, π_z, CI, LI, ϕ, verbose = true, vTol = 1e-8);

            diff = K - kval
            adj = abs(diff) < .1 ? 0.5 : 0.7 # fancy if-then in one line

            if diff > 0
                @printf("\n||K - kval|| = %4.5f. \tCapital too low.\n", abs(diff))
                kl = (1 - adj) * kval + adj * kl
            else
                @printf("\n||K - kval|| = %4.5f. \tCapital too high.\n", abs(diff))
                kh = (1 - adj) * kval + adj * kh
            end

            kdist = abs(diff)
            kval = 0.5 * (kl + kh)

        end
        
        # storing each steady state
        results[(η, τ)] = (
            V = V,
            G = G,
            C = C,
            μ = μ,
            K = kval,
            policies = policies
        )

        @save "steady_states.jld2" results params policies
    end
end
# Out:
# Solving (eta, tau) = (0.00, 0.00)--------------
#
#
# K guess: 10.00000000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000215, ||G - G0|| = 0.000000, dist = 0.000215
# 	Iteration 333: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 330: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 8.88304. 	Capital too high.
#
#
# K guess: 7.50000000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2439: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 21.79404. 	Capital too low.
#
#
# K guess: 8.62500000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000224, ||G - G0|| = 0.000000, dist = 0.000224
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 710: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 6.05413. 	Capital too high.
#
#
# K guess: 7.03125000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000224, ||G - G0|| = 0.000000, dist = 0.000224
# 	Iteration 333: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 580: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 60.78464. 	Capital too low.
#
#
# K guess: 7.74843750
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2580: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 3.31496. 	Capital too low.
#
#
# K guess: 8.76445312
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000223, ||G - G0|| = 0.000000, dist = 0.000223
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 630: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 6.47707. 	Capital too high.
#
#
# K guess: 8.00244141
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000227, ||G - G0|| = 0.000000, dist = 0.000227
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 1581: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 2.35146. 	Capital too high.
#
#
# K guess: 7.43093262
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2207: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 27.85654. 	Capital too low.
#
#
# K guess: 7.68811157
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2822: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 6.34630. 	Capital too low.
#
#
# K guess: 8.05244843
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000227, ||G - G0|| = 0.000000, dist = 0.000227
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 1451: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 2.89902. 	Capital too high.
#
#
# K guess: 7.77919579
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2417: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 2.15805. 	Capital too low.
#
#
# K guess: 7.98413527
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000227, ||G - G0|| = 0.000000, dist = 0.000227
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 1633: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 2.12579. 	Capital too high.
#
#
# K guess: 7.83043066
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2145: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 0.64589. 	Capital too low.
#
#
# K guess: 7.94570911
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 1749: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 1.59779. 	Capital too high.
#
#
# K guess: 7.85925027
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2040: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 0.03805. 	Capital too high.
# Solving (eta, tau) = (0.00, 0.11)--------------
#
#
# K guess: 10.00000000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000213, ||G - G0|| = 0.000000, dist = 0.000213
# 	Iteration 333: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 313: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 9.21070. 	Capital too high.
#
#
# K guess: 7.50000000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2691: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 19.27510. 	Capital too low.
#
#
# K guess: 8.62500000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000223, ||G - G0|| = 0.000000, dist = 0.000223
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 681: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 6.69365. 	Capital too high.
#
#
# K guess: 7.03125000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000225, ||G - G0|| = 0.000000, dist = 0.000225
# 	Iteration 333: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 808: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 60.82640. 	Capital too low.
#
#
# K guess: 7.74843750
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2705: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 1.16947. 	Capital too low.
#
#
# K guess: 8.76445312
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000222, ||G - G0|| = 0.000000, dist = 0.000222
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 603: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 7.05780. 	Capital too high.
#
#
# K guess: 8.00244141
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000227, ||G - G0|| = 0.000000, dist = 0.000227
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 1574: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 3.60077. 	Capital too high.
#
#
# K guess: 7.43093262
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2425: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 25.60906. 	Capital too low.
#
#
# K guess: 7.68811157
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 3052: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 3.85232. 	Capital too low.
#
#
# K guess: 8.05244843
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000226, ||G - G0|| = 0.000000, dist = 0.000226
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 1434: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 4.05384. 	Capital too high.
#
#
# K guess: 7.77919579
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2500: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 0.17730. 	Capital too low.
#
#
# K guess: 7.98413527
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000227, ||G - G0|| = 0.000000, dist = 0.000227
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
# 	Iteration 1630: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 3.41394. 	Capital too high.
#
#
# K guess: 7.83043066
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000227, ||G - G0|| = 0.000000, dist = 0.000227
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2215: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 1.10510. 	Capital too high.
#
#
# K guess: 7.71515220
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2915: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 2.50775. 	Capital too low.
#
#
# K guess: 7.80161104
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2355: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 0.43124. 	Capital too high.
#
#
# K guess: 7.73676691
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2781: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 1.60359. 	Capital too low.
#
#
# K guess: 7.78540001
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2459: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 0.00026. 	Capital too low.
# Solving (eta, tau) = (0.00, 0.22)--------------
#
#
# K guess: 10.00000000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000212, ||G - G0|| = 0.000000, dist = 0.000212
# 	Iteration 333: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 295: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 9.47874. 	Capital too high.
#
#
# K guess: 7.50000000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2960: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 16.69277. 	Capital too low.
#
#
# K guess: 8.62500000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000221, ||G - G0|| = 0.000000, dist = 0.000221
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 648: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 7.24324. 	Capital too high.
#
#
# K guess: 7.03125000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000226, ||G - G0|| = 0.000000, dist = 0.000226
# 	Iteration 333: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 946: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 60.25598. 	Capital too low.
#
#
# K guess: 7.74843750
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000227, ||G - G0|| = 0.000000, dist = 0.000227
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2802: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 0.79578. 	Capital too high.
#
#
# K guess: 6.73242188
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000221, ||G - G0|| = 0.000000, dist = 0.000221
# 	Iteration 331: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 1003: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 89.16567. 	Capital too low.
#
#
# K guess: 7.18962891
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 1100: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 45.34615. 	Capital too low.
#
#
# K guess: 7.57825488
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 3343: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 9.23978. 	Capital too low.
#
#
# K guess: 8.12880835
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000225, ||G - G0|| = 0.000000, dist = 0.000225
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 1221: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 5.52974. 	Capital too high.
#
#
# K guess: 7.71589325
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000227, ||G - G0|| = 0.000000, dist = 0.000227
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 3067: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 0.30823. 	Capital too low.
#
#
# K guess: 8.02557957
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000226, ||G - G0|| = 0.000000, dist = 0.000226
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 1480: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 4.88126. 	Capital too high.
#
#
# K guess: 7.79331483
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000227, ||G - G0|| = 0.000000, dist = 0.000227
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2462: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 1.94879. 	Capital too high.
#
#
# K guess: 7.61911627
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 3459: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 5.79994. 	Capital too low.
#
#
# K guess: 7.74976519
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000227, ||G - G0|| = 0.000000, dist = 0.000227
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2792: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 0.83541. 	Capital too high.
#
#
# K guess: 7.65177850
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 3437: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 3.50903. 	Capital too low.
#
#
# K guess: 7.72526852
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000227, ||G - G0|| = 0.000000, dist = 0.000227
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 2992: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 0.03851. 	Capital too high.
# Solving (eta, tau) = (0.00, 0.33)--------------
#
#
# K guess: 10.00000000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000210, ||G - G0|| = 0.000000, dist = 0.000210
# 	Iteration 332: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 275: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 9.68545. 	Capital too high.
#
#
# K guess: 7.50000000
# Solving Household Problem...
# 	Iteration 200: ||V - V0|| = 0.000228, ||G - G0|| = 0.000000, dist = 0.000228
# 	Iteration 334: ||V - V0|| = 0.000000, ||G - G0|| = 0.000000, dist = 0.000001
#
# 	Iteration 3249: ||Tm - m|| = 0.000000	sum = 1.0000
#
# ||K - kval|| = 14.08698. 	Capital too low.
# InterruptException:
#
# Stacktrace:
#  [1] try_yieldto(undo::typeof(Base.ensure_rescheduled))
#    @ Base .\task.jl:920
#  [2] wait()
#    @ Base .\task.jl:984
#  [3] uv_write(s::Base.PipeEndpoint, p::Ptr{UInt8}, n::UInt64)
#    @ Base .\stream.jl:1048
#  [4] unsafe_write(s::Base.PipeEndpoint, p::Ptr{UInt8}, n::UInt64)
#    @ Base .\stream.jl:1120
#  [5] unsafe_write
#    @ .\io.jl:430 [inlined]
#  [6] unsafe_write
#    @ .\io.jl:685 [inlined]
#  [7] write
#    @ .\io.jl:708 [inlined]
#  [8] format(io::IJulia.IJuliaStdio{Base.PipeEndpoint}, f::Printf.Format{Base.CodeUnits{UInt8, String}, Tuple{Printf.Spec{Val{'f'}}}}, args::Float64)
#    @ Printf C:\Users\unnav\AppData\Local\Programs\Julia-1.9.3\share\julia\stdlib\v1.9\Printf\src\Printf.jl:870
#  [9] top-level scope
#    @ .\In[7]:44
