# %% [markdown]
# # Krussel Smith Implementation
#
# Here is where I give a whack at getting Krussel Smith going. I am trying not to crash out (interesting strategy, let's see how it plays out).

# %%
# run if you don't have this package (I didn't), otherwise comment out
# import Pkg; Pkg.add("Printf"); Pkg.add("JLD2"); import Pkg; Pkg.add("Random"); Pkg.add("StatsBase");

# %%
using JLD2
using Random
using Printf
using LinearAlgebra: dot
using StatsBase: countmap

include("src/ModelTypes.jl")
@printf("Loaded ModelTypes.jl\n")

include("src/Compute.jl")
@printf("Loaded Compute.jl\n")

include("src/ModelFunctions.jl")
@printf("Loaded ModelFunctions.jl\n")

include("src/EGM.jl")
@printf("Loaded EGM.jl\n")

include("src/DistrTools.jl")
@printf("Loaded DistrTools.jl\n")

include("src/Solvers.jl")
@printf("Loaded Solvers.jl\n")

include("src/SteadyState.jl")
@printf("Loaded Steady States.jl\n")

include("src/Predict.jl")
@printf("Loaded Predict.jl\n")

using .ModelTypes
using .ModelFunctions
using .Compute
using .EGM
using .DistrTools
using .Solvers
using .SteadyState
using .Predict
# Out:
# Loaded ModelTypes.jl
# Loaded Compute.jl
# Loaded ModelFunctions.jl
# Loaded EGM.jl
# Loaded DistrTools.jl
# Loaded Solvers.jl
# Loaded Steady States.jl
# Loaded Predict.jl

# %%
# model parameters
const α::Float64 = 0.36;
const β::Float64 = 0.96;
const δ::Float64 = 0.06;
const σ::Float64 = 2;
const ϕ::Float64 = 0;

# grid sizes and parameters
const na::Int64 = 100; 
const nl::Int64 = 7;
const nz::Int64 = 5;
const nk::Int64 = 25;

const a_l::Float64 = 0;
const a_h::Float64 = 100;

# calibrations for idiosyncratic income (vibes)
const μ_l::Float64 = 0; 
const ρ_l::Float64 = .9;
const σ_l::Float64 = .2;

# calibrations for aggregate TFP (Khan and Thomas 2013 would have 
# ρ_z = 0.909; I am setting it lower for two dimensional z with
# some variance for now.)
const μ_z::Float64 = 0;
const ρ_z::Float64 = .909;
const σ_z::Float64 = 0.014;

# %%
grid_range = 2.575;

π_l, lgrid = getTauchen(nl,  μ_l, σ_l, ρ_l, grid_range);
π_z, zgrid= getTauchen(nz,  μ_z, σ_z, ρ_z, grid_range);

stationary_l = stationary(π_l);
const lagg::Float64 = dot(stationary_l, lgrid);
 
agrid = logspace(a_l, a_h, na);
amu = collect(range(a_l, a_h, length=na*10));

const kL::Float64 = 6; const kH::Float64 = 12; # this could be informed by steady states, but for now we do it this way
Kgrid = collect(range(kL, kH, length = nk));

# %%
const np::Int64 = 10; # number of policies
const pol_l::Float64 = 0;
const pol_h::Float64 = 1;

τ_grid = range(pol_l, pol_h, length = np);
η_grid = range(pol_l, pol_h, length = np);

captax = repeat([0], outer = nl);

η = 0; τ = 0;

# %% [markdown]
# Okay, so the goal here is that there are forecasts across moments of the aggregate capital distribution, which means that I have to send new prices to the household across capital moments and solve each household problem at each aggregate capital moment; then I simulate, check the accuracy of the forecasts with the actual responses to a TFP shock path, and then update my forecasts.
#
# What this means is that every aggregate capital moment generates a price, which leads to the solution of the household problem for each aggregate capital moment with uncertainty over TFP. To do that, I need to make a couple changes:
#
# 0. Choosing which steady state to start from--I need to import that stationary distribution.
# 1. Set up a forecasting rule. Here, I'll just set it to something like $\log(K') = 0.05 a + .95\log(K)$ for each transition z -> z' (so this is nz^2 forecasting rules)
# 2. Simulating a shock path: I want to keep this constant, so it's setting the RNG seed so that it spits out the same z path each time.
# 3. Then running regressions and updating--because I have effectively 4 rules, this should have several periods.

# %%
const NT = 5000; #three thousand periods for sampling
const rnseed = 1234567;

vec = simz(NT, nz, rnseed, π_z);

# forecasting rules: 
Kfore = repeat([0.05 0.95], nz, 1)
# Out:
# 5×2 Matrix{Float64}:
#  0.05  0.95
#  0.05  0.95
#  0.05  0.95
#  0.05  0.95
#  0.05  0.95

# %% [markdown]
# Now to do the actual solve:

# %%
V = nothing
EV = nothing
G = nothing  
C = nothing
CI = nothing
LI = nothing
μ = nothing

foredist = 10;
const dTol = 1e-3;
const vTol = 1e-6;


r_vals = zeros(nk, nz); w_vals = zeros(nk, nz); λ_vals = zeros(nk, nz); 

for ik = 1:nk
    for iz = 1:nz
        r_vals[ik, iz] = calcr(α, δ, Kgrid[ik], η, zgrid[iz])
        w_vals[ik, iz] = calcw(α, Kgrid[ik], η, zgrid[iz])
        denom = dot((w_vals[ik, iz] .* lgrid).^(1 - τ), stationary(π_l))
        tot_inc = w_vals[ik, iz] * dot(lgrid, stationary(π_l))
        λ_vals[ik, iz] = tot_inc / denom
    end
end

const params = ModelParams(α, β, δ, σ, ϕ, agrid, 
    lgrid, zgrid, π_l, π_z, amu, Kgrid);

const policies = ProposedPolicies(η, τ, captax);

const prices = ImpliedRegimeParams_KS(λ_vals, r_vals, w_vals)

# init V:

V0 = zeros(nk,nz,nl,na); V  = zeros(nk,nz,nl,na);
EV = zeros(nk,nz,nl,na); G  = zeros(nk,nz,nl,na); 
G0 = zeros(nk, nz, nl, na); C  = zeros(nk,nz,nl,na);

for ik = 1:nk
    for iz = 1:nz
        for il = 1:nl
            for ia = 1:na
                kval = agrid[ia];
                yval = (1 + r_vals[ik, iz]*(1-captax[il]))*kval + w_vals[ik, iz]*lgrid[il] - r_vals[ik, iz]*ϕ;
                ymin = max(1e-10, yval);
                V0[ik, iz, il, ia] = log(ymin);
                G0[ik, iz, il, ia] = agrid[ia];
            end
        end
    end
end

# %%
Kfore, Kt, zt = run_KS(V, V0, G, G0, C, params, policies, prices,
                NT, rnseed, vTol, dTol)

println(Kfore)
# Out:
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0
iters, dist = 0.000001
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
#
# Forecast rules:  log K' = a + b·log K
# ──────────────────────────────────────────────────────────
#   z-state            a           b        R²        n
# ──────────────────────────────────────────────────────────
#   1           0.103196    0.945970    1.0000      347
#   2           0.112816    0.943963    1.0000     1313
#   3           0.121807    0.942295    1.0000     1900
#   4           0.131485    0.940392    1.0000      853
#   5           0.139941    0.939208    1.0000       87
# ──────────────────────────────────────────────────────────
# Outer 10 | foredist = 0.002974 | R² = [1.0000, 1.0000, 1.0000, 1.0000, 1.0000] | counts = [347, 1313, 1900, 853, 87]
# Solving Household Problem...
# 	Converged in 52 iters, dist = 0.000001
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
#
# Forecast rules:  log K' = a + b·log K
# ──────────────────────────────────────────────────────────
#   z-state            a           b        R²        n
# ──────────────────────────────────────────────────────────
#   1           0.103083    0.946028    1.0000      347
#   2           0.112695    0.944023    1.0000     1313
#   3           0.121679    0.942356    1.0000     1900
#   4           0.131349    0.940454    1.0000      853
#   5           0.139796    0.939273    1.0000       87
# ──────────────────────────────────────────────────────────
# Outer 11 | foredist = 0.001937 | R² = [1.0000, 1.0000, 1.0000, 1.0000, 1.0000] | counts = [347, 1313, 1900, 853, 87]
# Solving Household Problem...
# 	Converged in 49 iters, dist = 0.000001
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
#
# Forecast rules:  log K' = a + b·log K
# ──────────────────────────────────────────────────────────
#   z-state            a           b        R²        n
# ──────────────────────────────────────────────────────────
#   1           0.103009    0.946065    1.0000      347
#   2           0.112616    0.944062    1.0000     1313
#   3           0.121595    0.942395    1.0000     1900
#   4           0.131260    0.940495    1.0000      853
#   5           0.139701    0.939315    1.0000       87
# ──────────────────────────────────────────────────────────
# Outer 12 | foredist = 0.001261 | R² = [1.0000, 1.0000, 1.0000, 1.0000, 1.0000] | counts = [347, 1313, 1900, 853, 87]
# Solving Household Problem...
# 	Converged in 45 iters, dist = 0.000001
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
#
# Forecast rules:  log K' = a + b·log K
# ──────────────────────────────────────────────────────────
#   z-state            a           b        R²        n
# ──────────────────────────────────────────────────────────
#   1           0.102962    0.946089    1.0000      347
#   2           0.112565    0.944087    1.0000     1313
#   3           0.121541    0.942421    1.0000     1900
#   4           0.131201    0.940522    1.0000      853
#   5           0.139639    0.939342    1.0000       87
# ──────────────────────────────────────────────────────────
# Outer 13 | foredist = 0.000821 | R² = [1.0000, 1.0000, 1.0000, 1.0000, 1.0000] | counts = [347, 1313, 1900, 853, 87]
#
# Converged in 13 outer iters. foredist = 0.000821
# UndefVarError: `Kt` not defined
#
# Stacktrace:
#  [1] run_KS(V::Array{Float64, 4}, V0::Array{Float64, 4}, G::Array{Float64, 4}, G0::Array{Float64, 4}, C::Array{Float64, 4}, params::ModelParams, policies::ProposedPolicies, prices::ImpliedRegimeParams_KS, NT::Int64, rnseed::Int64, vTol::Float64, dTol::Float64; burnin::Int64, λ_damp::Float64, maxout::Int64)
#    @ Main.Predict C:\VAASAVI\Dropbox\Education\OSU\Ongoing_Research\Populism\political-polarization\p\src\Predict.jl:179
#  [2] run_KS(V::Array{Float64, 4}, V0::Array{Float64, 4}, G::Array{Float64, 4}, G0::Array{Float64, 4}, C::Array{Float64, 4}, params::ModelParams, policies::ProposedPolicies, prices::ImpliedRegimeParams_KS, NT::Int64, rnseed::Int64, vTol::Float64, dTol::Float64)
#    @ Main.Predict C:\VAASAVI\Dropbox\Education\OSU\Ongoing_Research\Populism\political-polarization\p\src\Predict.jl:135
#  [3] top-level scope
#    @ In[8]:1

# %%
# storing each stationary equilibrium
results[(η, τ)] = (
    Kfore,
    V = V,
    G = G,
    C = C,
    Kt = kval,
    zt = zt,
    policies = policies
)
# Out:
# UndefVarError: `kval` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[9]:2

# %%
@save "../d/KS_solves.jld2" results params
# Out:
# UndefVarError: `results` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ C:\Users\unnav\.julia\packages\JLD2\qcxKY\src\loadsave.jl:72
