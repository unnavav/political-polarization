# %% [markdown]
# This is me trying to do endogenous regime change now. Hopefully it doesn't take that long? Idk sobbing this all feels exhausting wot am i doing

# %%
println("Adding Packages...\n")
using Pkg
Pkg.activate(".")   # so you're using the same packages as me
Pkg.instantiate(; verbose=true)

using JLD2
using Random
using Printf
using LinearAlgebra
using StatsBase: countmap, mean, median
using Dates
using Revise
# Out:
# Adding Packages...
#   Activating project at `C:\VAASAVI\Dropbox\Education\OSU\Ongoing_Research\Populism\political-polarization\p`

# %% [markdown]
# Now importing the relevant code that I've written: putting this in a different block because that means I can reimport it as needed without much chaos. This takes advantage of the revise module, which checks whether the module has already been loaded and updates if so.

# %%
for file in ["src/ModelTypes.jl", "src/Compute.jl", "src/DistrTools.jl", "src/ModelFunctions.jl",
             "src/EGM.jl", "src/Solvers.jl", "src/SteadyState.jl", "src/Predict.jl"]
    modname = Symbol(splitext(basename(file))[1])       # taken from claude, not sure this symbol thing yet
    existed = isdefined(Main, modname)
    includet(file)
    println(existed ? "Updated $file" : "Loaded $file")
end

using .ModelTypes, .Compute, .EGM, .DistrTools, .Solvers, .SteadyState, .Predict, .ModelFunctions
# Out:
# Loaded src/ModelTypes.jl
# Loaded src/Compute.jl
# Loaded src/DistrTools.jl
# Loaded src/ModelFunctions.jl
# Loaded src/EGM.jl
# Loaded src/Solvers.jl
# Loaded src/SteadyState.jl
# Loaded src/Predict.jl

# %% [markdown]
# Inititalizing the actual environment

# %%
# ─── Frequency-invariant parameters ───
const α::Float64 = 0.36
const σ::Float64 = 2
const ϕ::Float64 = 0
const μ_l::Float64 = 0
const μ_z::Float64 = 0

# grid sizes and parameters
const na::Int64 = 100; 
const nl::Int64 = 15;
const nz::Int64 = 2;
const nk::Int64 = 15;

const a_l::Float64 = 0;
const a_h::Float64 = 100;

# policy grids
const np::Int64 = 10; # number of policies
const pol_l::Float64 = 0;
const pol_h::Float64 = .18;

τ_grid = range(pol_l, pol_h, length = np);
η_grid = range(pol_l, pol_h, length = np);
policy_grid = [(η, τ) for η in η_grid, τ in τ_grid];
captax = repeat([0.0], outer = nl);

# ─── Frequency switch: read from environment, default to "annual" ───
const freq = get(ENV, "FREQ", "annual")
display("Frequency set to: $freq")

if freq == "quarterly"
    const β::Float64   = 0.99
    const δ::Float64   = 0.025
    const ρ_l::Float64 = 0.9878      # STY persistence quarterly
    const σ_l::Float64 = 0.087       # STY innovation std, quarterly
    const ρ_z::Float64 = 0.976
    const σ_z::Float64 = 0.007
    
			
elseif freq == "annual"
    const β::Float64   = 0.96
    const δ::Float64   = 0.06
    const ρ_l::Float64 = 0.952     # Storesletten-Telmer-Yaron
    const σ_l::Float64 = 0.17       # = sqrt(0.061), STY persistent innovation std σ_η
    const ρ_z::Float64 = 0.909      # Khan-Thomas 2013
    const σ_z::Float64 = 0.014
    
else
    error("FREQ must be \"annual\" or \"quarterly\", got \"$freq\"")
end

const freq_label = freq;   # use in output filename
# Out:
# "Frequency set to: annual"

# %% [markdown]
# Now building the grids

# %%
grid_range_l = 2.5     # wide, for near-unit-root labor
grid_range_z = 2.575   # leave z as is

π_l, lgrid = getTauchen(nl, μ_l, σ_l, ρ_l, grid_range_l);
# π_z, zgrid= getTauchen(nz,  μ_z, σ_z, ρ_z, grid_range_z);

# stationary_l = stationary(π_l);
# const lagg::Float64 = dot(stationary_l, lgrid);

zgrid = [0.98, 1.02]          # bad, good
π_z = [0.80  0.20;                 # from bad: 20% chance exit to good
       0.03125  0.96875]          # from good: ~3% chance enter recession

nt = length(LinearIndices(π_z));       # number of states in joint markov chain

stationary_l = stationary(π_l);
const lagg::Float64 = dot(stationary_l, lgrid);
 
# more conservative estimates 
# const kH::Float64 = ((1.0/β - 1.0 + δ) / α)^(1.0/(α-1.0)) * (1.0 + maximum(η_grid)) * 1.5
# const kL::Float64 = max(1.0, ((1.0/β - 1.0 + δ) / α)^(1.0/(α-1.0)) * (1.0 + minimum(η_grid)) * 0.5)

const kL::Float64 = 3; const kH::Float64 = 12; 
Kgrid = collect(range(kL, kH, length = nk));

agrid = logspace(a_l, a_h, na);
amu = collect(range(a_l, a_h, length=na*10));

const NT = 5000; #three thousand periods for sampling
const rnseed = 1234567;

const zt = simz(NT, nz, rnseed, π_z);

const params = ModelParams(α, β, δ, σ, ϕ, agrid, 
		lgrid, zgrid, π_l, π_z, amu, Kgrid);

lgrid

display(sum(stationary(π_l)))
# Out:
# 1.0000000000000269

# %% [markdown]
# The next thing that needs to be done is like, figuring out what to do to make this endogenous. I'm doing the first part, which is just running it to make sure I can get the forecasts based on z-z transitions, ignoring regime change for now.

# %%
Kfore_start = [ 0.151993    0.933069    0.002547; 
    0.1613271876906856 0.932123684433605 3.0517578125e-5; 
    0.160608262813353 0.9324243834645358 3.0517578125e-5; 
    0.151325    0.933213     3.0517578125e-5]

η1 = 0.0; τ = 0.0; captax = repeat([0.0], outer = nl); 
η2 = 0.08; 
policies1 = ProposedPolicies(η1, τ, captax);
policies2 = ProposedPolicies(η2, τ, captax);


r_vals = zeros(nk, nt); w_vals = zeros(nk, nt); λ_vals = zeros(nk, nt); 

for ik = 1:nk, it = 1:nt
	iz = CartesianIndices(π_z)[it][2] # getting today's z'
	r_vals[ik, it] = calcr(α, δ, Kgrid[ik], η1, zgrid[iz]);
	w_vals[ik, it] = calcw(α, Kgrid[ik], η1, zgrid[iz]);
	denom = dot((w_vals[ik, it] .* lgrid).^(1 - τ), stationary(π_l));
	tot_inc = w_vals[ik, it] * dot(lgrid, stationary(π_l));
	λ_vals[ik, it] = tot_inc / denom;
end
prices1 = ImpliedRegimeParams_KS(λ_vals, r_vals, w_vals);

r_vals = zeros(nk, nt); w_vals = zeros(nk, nt); λ_vals = zeros(nk, nt); 

for ik = 1:nk, it = 1:nt
	iz = CartesianIndices(π_z)[it][2] # getting today's z'
	r_vals[ik, it] = calcr(α, δ, Kgrid[ik], η2, zgrid[iz]);
	w_vals[ik, it] = calcw(α, Kgrid[ik], η2, zgrid[iz]);
	denom = dot((w_vals[ik, it] .* lgrid).^(1 - τ), stationary(π_l));
	tot_inc = w_vals[ik, it] * dot(lgrid, stationary(π_l));
	λ_vals[ik, it] = tot_inc / denom;
end
prices2 = ImpliedRegimeParams_KS(λ_vals, r_vals, w_vals);

extrema(prices1.r .- prices2.r)
prices2.r[cld(nk, 2),1]

prices1.r
# Out:
# 15×4 Matrix{Float64}:
#  0.114651   0.114651   0.12178    0.12178
#  0.0942431  0.0942431  0.100539   0.100539
#  0.0790061  0.0790061  0.0846798  0.0846798
#  0.0671122  0.0671122  0.0723004  0.0723004
#  0.0575195  0.0575195  0.0623162  0.0623162
#  0.0495868  0.0495868  0.0540597  0.0540597
#  0.0428956  0.0428956  0.0470955  0.0470955
#  0.0371604  0.0371604  0.0411261  0.0411261
#  0.0321789  0.0321789  0.0359413  0.0359413
#  0.0278034  0.0278034  0.0313872  0.0313872
#  0.0239234  0.0239234  0.0273489  0.0273489
#  0.0204545  0.0204545  0.0237383  0.0237383
#  0.0173307  0.0173307  0.0204871  0.0204871
#  0.0145     0.0145     0.0175408  0.0175408
#  0.0119205  0.0119205  0.014856   0.014856

# %% [markdown]
# Now we start the actual solution part.

# %%
# put this in again here since I'm testing and modifying regularly.

for file in ["src/ModelTypes.jl", "src/Compute.jl", "src/DistrTools.jl", "src/ModelFunctions.jl",
             "src/EGM.jl", "src/Solvers.jl", "src/SteadyState.jl", "src/Predict.jl"]
    modname = Symbol(splitext(basename(file))[1])       # taken from claude, not sure this symbol thing yet
    existed = isdefined(Main, modname)
    includet(file)
    println(existed ? "Updated $file" : "Loaded $file")
end

# init V and friends:
V0 = zeros(nk,nt,nl,na); V  = zeros(nk,nt,nl,na);
G0 = zeros(nk,nt,nl,na); G  = zeros(nk,nt,nl,na);  
C  = zeros(nk,nt,nl,na);

# intializing a starting guess
for ik = 1:nk, it = 1:nt, il = 1:nl, ia = 1:na
	kval = agrid[ia];
	yval = (1 + r_vals[ik, it]*(1-captax[il]))*kval + w_vals[ik, it]*lgrid[il] - r_vals[ik, it]*ϕ;
	ymin = max(1e-10, yval);
	V0[ik, it, il, ia] = log(ymin);
	G0[ik, it, il, ia] = agrid[ia];
end

const dTol = 1e-4;
const vTol = 1e-4;


verbose = true;
# Out:
# Updated src/ModelTypes.jl
# Updated src/Compute.jl
# Updated src/DistrTools.jl
# Updated src/ModelFunctions.jl
# Updated src/EGM.jl
# Updated src/Solvers.jl
# Updated src/SteadyState.jl
# Updated src/Predict.jl

# %%
# put this in again here since I'm testing and modifying regularly.

for file in ["src/ModelTypes.jl", "src/Compute.jl", "src/DistrTools.jl", "src/ModelFunctions.jl",
             "src/EGM.jl", "src/Solvers.jl", "src/SteadyState.jl", "src/Predict.jl"]
    modname = Symbol(splitext(basename(file))[1])       # taken from claude, not sure this symbol thing yet
    existed = isdefined(Main, modname)
    includet(file)
    println(existed ? "Updated $file" : "Loaded $file")
end

foredist = 10.0
outer_ct = 1
maxout = 25;

Kt = zeros(Float64, NT+1); 
it_t = zeros(Int, NT);
votes_t = zeros(Float64, NT);

Kfore = copy(Kfore_start);

burnin  = 500; λ_damp = 0.3;

# Pkg.add("CodeTracking")
using CodeTracking
using ..DistrTools
methods(transitDistr)
println(@code_string genForecastData(V, V0, G, G0, C, Kfore, params, policies1, policies2, prices1, prices2, zt, vTol; verbose))
# Out:
# Updated src/ModelTypes.jl
# Updated src/Compute.jl
# Updated src/DistrTools.jl
# Updated src/ModelFunctions.jl
# Updated src/EGM.jl
# Updated src/Solvers.jl
# Updated src/SteadyState.jl
# Updated src/Predict.jl
# function genForecastData(V, V0, G, G0, C, Kfore, params, policies1, policies2,
#                     prices1, prices2, zt, vTol; verbose = false)
#
# 	CI = CartesianIndices(params.π_z)   # (nz,nz) for getDistr
# 	LI = LinearIndices(params.π_z)
#
# 	nk, nt, nl, na = size(V);
# 	Kgrid = params.Kgrid;
#
#     futureKs = exp.(Kfore[:, 1] .+ Kfore[:, 2] .* log.(Kgrid)')
#     @assert size(futureKs) == (nt, nk)
#
#     V1, G1, C1, ~, ~ = KSsolver(copy(V), copy(V0), copy(G), copy(G0), copy(C),
#         futureKs, Kgrid, params, policies1, prices1, CI, LI, vTol; verbose)
#     V2, G2, C2, ~, ~ = KSsolver(copy(V), copy(V0), copy(G), copy(G0), copy(C),
#         futureKs, Kgrid, params, policies2, prices2, CI, LI, vTol; verbose)
#
#     EV1 = getExpectationKS(futureKs, V1, params, CI, LI)
#     EV2 = getExpectationKS(futureKs, V2, params, CI, LI)
#
#     VOTES = zeros(nk,nt,nl,na);
#     for it in 1:nt
#         VOTES[:,it,:,:] = Int.(EV1[:, it, :, :] .> EV2[:, it, :, :]);
#     end
#
# 	# choose a random starting point for the simulation
#     NT = length(zt);
#     ik0 = cld(nk, 2); K0 = Kgrid[ik0];
#     Kt = zeros(NT+1); Kt[1] = Kgrid[ik0]
#
#     # initial distribution: stationary at starting K, lifted to pair-state
#     G_start = G1[ik0, :, :, :]                        # (nt, nl,na) (base K)
#
#     println("G1 across pairs: ", extrema(G1[ik0, 1, :, :] .- G1[ik0, 4, :, :]))
#     println("G1 vs G2 (η effect): ", extrema(G1 .- G2))
#     println("G1 === G2: ", G1 === G2)
#     println("prices1.r === prices2.r: ", prices1.r == prices2.r)  # should be FALSE
#     println("G1 vs G2 extrema: ", extrema(G1 .- G2))              # you have this: (0,0)    # ... lift to pair-state (nz²) if getDistr is pair-state ...
#     μ_transit, _ = getDistr(G_start, params.amu, params.agrid, params.π_l, params.π_z,
#                          CI, LI, params.ϕ)
#
# 	#@printf("getDistr: sum(μ_prev) = %.10f  (want 1.0)\n", sum(μ_prev))
# 	#@printf("          min = %.3e  (want ≥ 0, no negatives)\n", minimum(μ_prev))
#
# 	#@printf("collapse: sum(μ_today) = %.10f  (want = sum(μ_prev))\n", sum(μ_today))
#     med_ind = ceil(Int, median(1:length(params.zgrid)))
#     it_t = zeros(Int, NT);
#     it_t[1] = LI[med_ind, med_ind]   # initial pair-state index
#     it_t[2:NT] = [LI[zt[t-1], zt[t]] for t in 2:NT];
#     μ_transit = μ_transit[it_t[1], :, :]
#     votes_t = zeros(Float64, NT);
#
#     a = copy(μ_transit);
# 	for t in 1:NT
# 		if t%2500 == 0 && verbose
# 			@printf("\tSimulating period %i of %i\n", t, NT)
# 		end
#
#         # getting today's vote to be used for tomorrow.
# 		K = Kt[t]; ix, we = weight(Kgrid, K);
# 		it = it_t[t] # getting which z transition we're in
#         VOTES_t = we.*VOTES[ix, it, :, :] + (1-we) .* VOTES[ix+1, it, :, :];
#         _, voteshare = mapVotes(VOTES_t, params, μ_transit)
#         votes_t[t] = voteshare;
#
# 		# update the distribution for the next period
#         G_t = we .* G1[ix, it, :, :] .+ (1-we) .* G1[ix+1, it, :, :];   # (nl, na)
# 		mass_before = sum(μ_transit)
# 		μ_transit, Kt[t+1] = transitDistr(G_t, μ_transit, params.amu, params.agrid, params.ϕ, params.π_l)
# 		mass_after = sum(μ_transit)
#
# 		if abs(mass_after - mass_before) > 1e-8
# 			@printf("LEAK at t=%i: before=%.10f after=%.10f  Δ=%.3e  (K=%.4f)\n",
# 					t, mass_before, mass_after, mass_after - mass_before, K)
# 		end
#
# 	end
#
#     println("Distribution changed: ", !(a ≈ μ_transit))
#     println("Max abs change: ", maximum(abs.(a .- μ_transit)))
#
# 	return Kt, it_t, votes_t
#
# end

# %%
while foredist > dTol && outer_ct ≤ maxout

    # vTol_outer = max(vTol, foredist * 1e-2)
    vTol_outer = vTol;

    # solve HH + simulate under current Kfore
    Kt, it_t, votes_t = genForecastData(V, V0, G, G0, C, Kfore, params, policies1,
                            policies2, prices1, prices2, zt, vTol_outer, verbose = verbose)

    Kfore_new, R2, counts = update_forecast(Kt, it_t, votes_t, nt, burnin)
    foredist = maximum(abs.(Kfore_new[:,1:2] .- Kfore[:,1:2]))

    if verbose
        CI = CartesianIndices(params.π_z)
        println("\nForecast rules:  log K' = a + b·log K")
        println("─"^72)
        @printf("  %-10s %11s %11s %11s %9s %8s\n", "z₋₁→z", "a", "b", "c(Θ)", "R²", "n")
        println("─"^72)
        for z1z2 in 1:nt
            zprev, znow = CI[z1z2][1], CI[z1z2][2]
            flag = (isnan(R2[z1z2]) || R2[z1z2] < 0.99) ? "  ⚠" : ""
            @printf("  %2d→%-6d %11.6f %11.6f %11.6f %9.4f %8d%s\n",
                zprev, znow, Kfore_new[z1z2,1], Kfore_new[z1z2,2],
                Kfore_new[z1z2, 3], R2[z1z2], counts[z1z2], flag)
        end
        println("─"^62)
        @printf("Outer %2i | foredist = %.6f\n", outer_ct, foredist)
        @printf("K range for (%4.2f, %4.2f) vs (%4.2f, %4.2f): %2.4f, %2.4f\n",
            policies1.η, policies1.τ, policies2.η, policies2.τ,
            minimum(Kt[501:end]), maximum(Kt[501:end]))

        summarizeKtByTransition(Kt, it_t, params.π_z, burnin)
    end

    # damped update
    Kfore = λ_damp .* Kfore_new .+ (1 - λ_damp) .* Kfore
    outer_ct += 1
end

converged = foredist <= dTol
if converged
    if verbose
        @printf("\nConverged in %i outer iters. foredist = %.6f\n", outer_ct-1, foredist)
    end
else
    # always report failure, regardless of verbose
    @printf("\n Hit maxout=%i without converging. foredist = %.6f\n", maxout, foredist)
    @printf("Maxout at policy (η, τ) = (%4.2f, %4.2f) vs (%4.2f, %4.2f)\n", 
        policies1.η, policies1.τ, policies2.η, policies2.τ)
end

a;ldkfajl
# Out:
# Solving Household Problem...
# 	Converged in 97 iters, dist = 0.000097
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000140, ||G - G0|| = 0.000000, dist = 0.000140
# 	Converged in 109 iters, dist = 0.000096
# G1 across pairs: (-0.0004025535352383258, 0.0003633352522736111)
# G1 vs G2 (η effect): (-0.448863728828357, 0.011866425658200175)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.448863728828357, 0.011866425658200175)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.00678890817150259
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.108676    0.933804    0.060290    1.0000      641
#    2→1         0.087567    0.936419    0.085450    1.0000      135
#    1→2         0.108186    0.933857    0.060889    1.0000      135
#    2→2         0.089387    0.936062    0.083746    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer  1 | foredist = 0.073760
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.0034, 9.0042
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.0037     0.0002     9.0034     9.0037     9.0042
#    2→1          135     9.0035     0.0002     9.0034     9.0034     9.0040
#    1→2          135     9.0037     0.0002     9.0034     9.0037     9.0042
#    2→2         3589     9.0035     0.0001     9.0034     9.0034     9.0042
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.0035     0.0002     9.0034     9.0035     9.0042
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000234, ||G - G0|| = 0.000000, dist = 0.000234
# 	Converged in 117 iters, dist = 0.000096
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000275, ||G - G0|| = 0.000000, dist = 0.000275
# 	Converged in 116 iters, dist = 0.000097
# G1 across pairs: (-0.013512339486032143, 0.02142250392682854)
# G1 vs G2 (η effect): (-0.36947104243797924, 0.03316232885370907)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.36947104243797924, 0.03316232885370907)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.006678951087678535
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.135555    0.939690    0.016145    1.0000      641
#    2→1         0.146472    0.937036    0.005570    1.0000      135
#    1→2         0.136178    0.939542    0.016517    1.0000      135
#    2→2         0.150097    0.936114    0.003107    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer  2 | foredist = 0.010506
# K range for (0.00, 0.00) vs (0.08, 0.00): 10.6156, 10.6939
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641    10.6626     0.0175    10.6164    10.6654    10.6895
#    2→1          135    10.6823     0.0140    10.6339    10.6881    10.6939
#    1→2          135    10.6603     0.0176    10.6156    10.6623    10.6895
#    2→2         3589    10.6819     0.0125    10.6194    10.6863    10.6939
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500    10.6786     0.0155    10.6156    10.6838    10.6939
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000203, ||G - G0|| = 0.000000, dist = 0.000203
# 	Converged in 116 iters, dist = 0.000096
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000305, ||G - G0|| = 0.000000, dist = 0.000305
# 	Converged in 121 iters, dist = 0.000098
# G1 across pairs: (-0.0028960484782238893, 0.004104961614388003)
# G1 vs G2 (η effect): (-0.3896106296431867, 0.025907136039541978)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.3896106296431867, 0.025907136039541978)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007064732272569867
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.132996    0.939629    0.015493    1.0000      641
#    2→1         0.121877    0.942529    0.024845    1.0000      135
#    1→2         0.132471    0.939763    0.016188    1.0000      135
#    2→2         0.123096    0.942230    0.023944    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer  3 | foredist = 0.019647
# K range for (0.00, 0.00) vs (0.08, 0.00): 10.2283, 10.2492
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641    10.2410     0.0047    10.2285    10.2418    10.2482
#    2→1          135    10.2461     0.0037    10.2332    10.2476    10.2492
#    1→2          135    10.2404     0.0047    10.2283    10.2409    10.2482
#    2→2         3589    10.2460     0.0033    10.2293    10.2472    10.2492
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500    10.2451     0.0041    10.2283    10.2465    10.2492
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000209, ||G - G0|| = 0.000000, dist = 0.000209
# 	Converged in 116 iters, dist = 0.000098
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000304, ||G - G0|| = 0.000000, dist = 0.000304
# 	Converged in 121 iters, dist = 0.000095
# G1 across pairs: (-0.006631157572617674, 0.009575093611317698)
# G1 vs G2 (η effect): (-0.3868847678223375, 0.02636781546717959)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.3868847678223375, 0.02636781546717959)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007150410392760006
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.133244    0.939427    0.016412    1.0000      641
#    2→1         0.123782    0.941705    0.025565    1.0000      135
#    1→2         0.133136    0.939431    0.017083    1.0000      135
#    2→2         0.123861    0.941656    0.026055    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer  4 | foredist = 0.012988
# K range for (0.00, 0.00) vs (0.08, 0.00): 10.2523, 10.2901
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641    10.2751     0.0085    10.2527    10.2765    10.2881
#    2→1          135    10.2845     0.0067    10.2611    10.2873    10.2901
#    1→2          135    10.2740     0.0085    10.2523    10.2750    10.2881
#    2→2         3589    10.2843     0.0060    10.2541    10.2864    10.2901
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500    10.2827     0.0074    10.2523    10.2852    10.2901
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000214, ||G - G0|| = 0.000000, dist = 0.000214
# 	Converged in 116 iters, dist = 0.000099
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000302, ||G - G0|| = 0.000000, dist = 0.000302
# 	Converged in 120 iters, dist = 0.000098
# G1 across pairs: (-0.009451521969299215, 0.013847066821398357)
# G1 vs G2 (η effect): (-0.3842844604633058, 0.02694829202138882)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.3842844604633058, 0.02694829202138882)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007197825864270451
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.128955    0.940357    0.021502    1.0000      641
#    2→1         0.126197    0.941021    0.024394    1.0000      135
#    1→2         0.129736    0.940153    0.021480    1.0000      135
#    2→2         0.127900    0.940556    0.023659    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer  5 | foredist = 0.008549
# K range for (0.00, 0.00) vs (0.08, 0.00): 10.2812, 10.3330
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641    10.3124     0.0116    10.2818    10.3142    10.3301
#    2→1          135    10.3253     0.0092    10.2933    10.3292    10.3330
#    1→2          135    10.3108     0.0116    10.2812    10.3122    10.3301
#    2→2         3589    10.3251     0.0083    10.2837    10.3280    10.3330
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500    10.3229     0.0102    10.2812    10.3263    10.3330
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000215, ||G - G0|| = 0.000000, dist = 0.000215
# 	Converged in 116 iters, dist = 0.000099
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000302, ||G - G0|| = 0.000000, dist = 0.000302
# 	Converged in 120 iters, dist = 0.000098
# G1 across pairs: (-0.00738498290479539, 0.010805010347667121)
# G1 vs G2 (η effect): (-0.38362403783787613, 0.02683511358853785)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.38362403783787613, 0.02683511358853785)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.00723038638698513
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.131592    0.939620    0.019625    1.0000      641
#    2→1         0.126654    0.940820    0.024484    1.0000      135
#    1→2         0.131935    0.939516    0.019899    1.0000      135
#    2→2         0.128179    0.940403    0.023751    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer  6 | foredist = 0.003609
# K range for (0.00, 0.00) vs (0.08, 0.00): 10.2871, 10.3274
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641    10.3114     0.0091    10.2875    10.3129    10.3252
#    2→1          135    10.3215     0.0072    10.2965    10.3245    10.3274
#    1→2          135    10.3102     0.0091    10.2871    10.3112    10.3252
#    2→2         3589    10.3213     0.0064    10.2890    10.3236    10.3274
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500    10.3196     0.0080    10.2871    10.3223    10.3274
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000215, ||G - G0|| = 0.000000, dist = 0.000215
# 	Converged in 116 iters, dist = 0.000099
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000302, ||G - G0|| = 0.000000, dist = 0.000302
# 	Converged in 120 iters, dist = 0.000098
# G1 across pairs: (-0.007056408764528843, 0.010315289053480114)
# G1 vs G2 (η effect): (-0.3835142159018261, 0.026733031821195574)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.3835142159018261, 0.026733031821195574)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007258059732076884
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.131706    0.939541    0.019739    1.0000      641
#    2→1         0.126808    0.940768    0.024371    1.0000      135
#    1→2         0.132037    0.939439    0.020007    1.0000      135
#    2→2         0.126101    0.940926    0.025537    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer  7 | foredist = 0.004358
# K range for (0.00, 0.00) vs (0.08, 0.00): 10.2841, 10.3223
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641    10.3071     0.0086    10.2845    10.3085    10.3202
#    2→1          135    10.3166     0.0068    10.2931    10.3195    10.3223
#    1→2          135    10.3060     0.0086    10.2841    10.3069    10.3202
#    2→2         3589    10.3165     0.0061    10.2860    10.3186    10.3223
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500    10.3148     0.0075    10.2841    10.3174    10.3223
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000217, ||G - G0|| = 0.000000, dist = 0.000217
# 	Converged in 116 iters, dist = 0.000100
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000301, ||G - G0|| = 0.000000, dist = 0.000301
# 	Converged in 120 iters, dist = 0.000096
# G1 across pairs: (-0.0077632158947325, 0.011403337619157128)
# G1 vs G2 (η effect): (-0.3822868319207089, 0.02701457023336573)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.3822868319207089, 0.02701457023336573)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007276228815387991
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.130267    0.939913    0.021264    1.0000      641
#    2→1         0.151830    0.934865    0.000260    1.0000      135
#    1→2         0.130702    0.939789    0.021450    1.0000      135
#    2→2         0.152840    0.934601   -0.000106    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer  8 | foredist = 0.023688
# K range for (0.00, 0.00) vs (0.08, 0.00): 10.3015, 10.3427
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641    10.3263     0.0092    10.3019    10.3278    10.3404
#    2→1          135    10.3366     0.0074    10.3112    10.3397    10.3427
#    1→2          135    10.3250     0.0093    10.3015    10.3261    10.3404
#    2→2         3589    10.3365     0.0066    10.3035    10.3388    10.3427
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500    10.3347     0.0082    10.3015    10.3374    10.3427
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000176, ||G - G0|| = 0.000000, dist = 0.000176
# 	Converged in 113 iters, dist = 0.000098
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000302, ||G - G0|| = 0.000000, dist = 0.000302
# 	Converged in 122 iters, dist = 0.000098
# G1 across pairs: (-0.00906861358679123, 0.006536500719382499)
# G1 vs G2 (η effect): (-0.39841675098645624, 0.022790378191066107)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.39841675098645624, 0.022790378191066107)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007418300905295062
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.135506    0.935867    0.025329    1.0000      641
#    2→1         0.157901    0.931145    0.002012    1.0000      135
#    1→2         0.134415    0.936126    0.025926    1.0000      135
#    2→2         0.158543    0.931088    0.000569    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer  9 | foredist = 0.022424
# K range for (0.00, 0.00) vs (0.08, 0.00): 10.0219, 10.0540
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641    10.0350     0.0072    10.0240    10.0337    10.0537
#    2→1          135    10.0266     0.0057    10.0219    10.0241    10.0463
#    1→2          135    10.0360     0.0072    10.0240    10.0353    10.0540
#    2→2         3589    10.0267     0.0052    10.0219    10.0249    10.0523
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500    10.0282     0.0064    10.0219    10.0259    10.0540
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000151, ||G - G0|| = 0.000000, dist = 0.000151
# 	Converged in 110 iters, dist = 0.000098
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000293, ||G - G0|| = 0.000000, dist = 0.000293
# 	Converged in 122 iters, dist = 0.000099
# G1 across pairs: (-0.024875942485508062, 0.018390306754656027)
# G1 vs G2 (η effect): (-0.40707451366007774, 0.021645751041997396)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.40707451366007774, 0.021645751041997396)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007345582461096842
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.132651    0.936362    0.027075    1.0000      641
#    2→1         0.156859    0.931557    0.000914    1.0000      135
#    1→2         0.130379    0.936962    0.027714    1.0000      135
#    2→2         0.155586    0.932050    0.000056    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer 10 | foredist = 0.014655
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.8766, 9.9705
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.9148     0.0212     9.8824     9.9110     9.9696
#    2→1          135     9.8904     0.0168     9.8766     9.8832     9.9483
#    1→2          135     9.9177     0.0212     9.8825     9.9154     9.9705
#    2→2         3589     9.8907     0.0151     9.8766     9.8853     9.9658
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.8950     0.0188     9.8766     9.8884     9.9705
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000137, ||G - G0|| = 0.000000, dist = 0.000137
# 	Converged in 108 iters, dist = 0.000098
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000287, ||G - G0|| = 0.000000, dist = 0.000287
# 	Converged in 122 iters, dist = 0.000098
# G1 across pairs: (-0.03702536439170956, 0.0276003561618694)
# G1 vs G2 (η effect): (-0.411314662307376, 0.02133084693494114)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.411314662307376, 0.02133084693494114)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007258757539717222
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.157379    0.931612   -0.000268    1.0000      641
#    2→1         0.151615    0.932724    0.005404    1.0000      135
#    1→2         0.155397    0.932114   -0.000317    1.0000      135
#    2→2         0.151498    0.933030    0.002615    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer 11 | foredist = 0.024268
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.8033, 9.9461
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.8612     0.0322     9.8120     9.8554     9.9446
#    2→1          135     9.8243     0.0256     9.8033     9.8133     9.9124
#    1→2          135     9.8656     0.0322     9.8121     9.8621     9.9461
#    2→2         3589     9.8248     0.0230     9.8033     9.8166     9.9389
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.8312     0.0286     9.8033     9.8213     9.9461
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000126, ||G - G0|| = 0.000000, dist = 0.000126
# 	Converged in 106 iters, dist = 0.000099
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000282, ||G - G0|| = 0.000000, dist = 0.000282
# 	Converged in 122 iters, dist = 0.000097
# G1 across pairs: (-0.0213307894760959, 0.016381067313732345)
# G1 vs G2 (η effect): (-0.4143089891719711, 0.02019968292446972)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.4143089891719711, 0.02019968292446972)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007293687743229342
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.153099    0.932793    0.001279    1.0000      641
#    2→1         0.149363    0.933328    0.005742    1.0000      135
#    1→2         0.151759    0.933080    0.001624    1.0000      135
#    2→2         0.150168    0.933380    0.002996    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer 12 | foredist = 0.012707
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.7571, 9.8422
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.7916     0.0192     9.7623     9.7883     9.8413
#    2→1          135     9.7697     0.0153     9.7571     9.7631     9.8222
#    1→2          135     9.7942     0.0192     9.7623     9.7921     9.8422
#    2→2         3589     9.7700     0.0137     9.7571     9.7651     9.8381
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.7738     0.0170     9.7571     9.7679     9.8422
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000122, ||G - G0|| = 0.000000, dist = 0.000122
# 	Converged in 106 iters, dist = 0.000096
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000280, ||G - G0|| = 0.000000, dist = 0.000280
# 	Converged in 122 iters, dist = 0.000097
# G1 across pairs: (-0.01253401807149146, 0.009748021713201549)
# G1 vs G2 (η effect): (-0.4152383430372595, 0.019692037014749086)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.4152383430372595, 0.019692037014749086)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007315624061079761
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.126252    0.937769    0.029859    1.0000      641
#    2→1         0.150876    0.933255    0.002626    1.0000      135
#    1→2         0.125161    0.938004    0.030354    1.0000      135
#    2→2         0.151572    0.933209    0.000899    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer 13 | foredist = 0.017952
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.7432, 9.7940
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.7639     0.0114     9.7464     9.7620     9.7934
#    2→1          135     9.7508     0.0092     9.7432     9.7468     9.7821
#    1→2          135     9.7654     0.0114     9.7465     9.7641     9.7940
#    2→2         3589     9.7510     0.0082     9.7432     9.7481     9.7916
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.7532     0.0102     9.7432     9.7498     9.7940
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000127, ||G - G0|| = 0.000000, dist = 0.000127
# 	Converged in 106 iters, dist = 0.000100
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000282, ||G - G0|| = 0.000000, dist = 0.000282
# 	Converged in 122 iters, dist = 0.000097
# G1 across pairs: (-0.030746363291726198, 0.023362435852535057)
# G1 vs G2 (η effect): (-0.4144289807489514, 0.02062421582941676)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.4144289807489514, 0.02062421582941676)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007225231155625543
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.151112    0.933164    0.004005    1.0000      641
#    2→1         0.147134    0.933692    0.008807    1.0000      135
#    1→2         0.148542    0.933721    0.005099    1.0000      135
#    2→2         0.147985    0.933791    0.005330    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer 14 | foredist = 0.012294
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.7559, 9.8782
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.8055     0.0275     9.7634     9.8007     9.8770
#    2→1          135     9.7740     0.0220     9.7559     9.7646     9.8495
#    1→2          135     9.8093     0.0275     9.7635     9.8062     9.8782
#    2→2         3589     9.7744     0.0197     9.7559     9.7674     9.8723
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.7799     0.0245     9.7559     9.7714     9.8782
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000130, ||G - G0|| = 0.000000, dist = 0.000130
# 	Converged in 107 iters, dist = 0.000098
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000284, ||G - G0|| = 0.000000, dist = 0.000284
# 	Converged in 122 iters, dist = 0.000098
# G1 across pairs: (-0.019083520553607514, 0.014659809537266533)
# G1 vs G2 (η effect): (-0.4134989685577324, 0.020418195598256084)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.4134989685577324, 0.020418195598256084)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.0072717251251115615
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.153781    0.932762    0.000246    1.0000      641
#    2→1         0.153924    0.932625    0.000350    1.0000      135
#    1→2         0.152865    0.932958    0.000295    1.0000      135
#    2→2         0.153037    0.932914   -0.000153    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer 15 | foredist = 0.011940
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.7769, 9.8539
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.8082     0.0173     9.7817     9.8053     9.8531
#    2→1          135     9.7884     0.0139     9.7769     9.7824     9.8359
#    1→2          135     9.8106     0.0173     9.7818     9.8086     9.8539
#    2→2         3589     9.7886     0.0125     9.7769     9.7842     9.8503
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.7921     0.0155     9.7769     9.7868     9.8539
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000115, ||G - G0|| = 0.000000, dist = 0.000115
# 	Converged in 104 iters, dist = 0.000100
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000277, ||G - G0|| = 0.000000, dist = 0.000277
# 	Converged in 122 iters, dist = 0.000096
# G1 across pairs: (-0.012594851298175058, 0.009900653364801393)
# G1 vs G2 (η effect): (-0.4172192047701202, 0.019329092095464517)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.4172192047701202, 0.019329092095464517)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.0072862295763532915
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.125110    0.937938    0.030608    1.0000      641
#    2→1         0.150226    0.933444    0.002608    1.0000      135
#    1→2         0.124216    0.938095    0.031065    1.0000      135
#    2→2         0.150894    0.933385    0.000993    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer 16 | foredist = 0.020779
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.7100, 9.7617
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.7310     0.0116     9.7132     9.7291     9.7611
#    2→1          135     9.7177     0.0093     9.7100     9.7137     9.7497
#    1→2          135     9.7326     0.0116     9.7133     9.7312     9.7617
#    2→2         3589     9.7179     0.0084     9.7100     9.7150     9.7593
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.7202     0.0104     9.7100     9.7167     9.7617
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000124, ||G - G0|| = 0.000000, dist = 0.000124
# 	Converged in 106 iters, dist = 0.000098
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000280, ||G - G0|| = 0.000000, dist = 0.000280
# 	Converged in 122 iters, dist = 0.000097
# G1 across pairs: (-0.03139510241327059, 0.023912213876465138)
# G1 vs G2 (η effect): (-0.415237026045304, 0.02052434283099691)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.415237026045304, 0.02052434283099691)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007206083924150254
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.151600    0.933128    0.003091    1.0000      641
#    2→1         0.153684    0.932593    0.001024    1.0000      135
#    1→2         0.149270    0.933622    0.003966    1.0000      135
#    2→2         0.152571    0.932948    0.000124    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer 17 | foredist = 0.011945
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.7418, 9.8676
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.7928     0.0283     9.7495     9.7879     9.8663
#    2→1          135     9.7604     0.0226     9.7418     9.7508     9.8381
#    1→2          135     9.7967     0.0283     9.7496     9.7935     9.8676
#    2→2         3589     9.7609     0.0203     9.7418     9.7536     9.8615
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.7665     0.0252     9.7418     9.7578     9.8676
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000114, ||G - G0|| = 0.000000, dist = 0.000114
# 	Converged in 104 iters, dist = 0.000099
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000276, ||G - G0|| = 0.000000, dist = 0.000276
# 	Converged in 122 iters, dist = 0.000096
# G1 across pairs: (-0.02260237664249587, 0.017585898471561112)
# G1 vs G2 (η effect): (-0.41766182923221606, 0.01965742306367746)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.41766182923221606, 0.01965742306367746)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007229313845862176
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.152269    0.933112    0.000815    1.0000      641
#    2→1         0.150887    0.933250    0.002508    1.0000      135
#    1→2         0.151275    0.933268    0.001008    1.0000      135
#    2→2         0.151058    0.933301    0.000903    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer 18 | foredist = 0.009600
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.6994, 9.7918
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.7368     0.0208     9.7050     9.7332     9.7908
#    2→1          135     9.7131     0.0166     9.6994     9.7060     9.7702
#    1→2          135     9.7396     0.0208     9.7051     9.7373     9.7918
#    2→2         3589     9.7135     0.0149     9.6995     9.7082     9.7874
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.7176     0.0185     9.6994     9.7113     9.7918
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000110, ||G - G0|| = 0.000000, dist = 0.000110
# 	Converged in 104 iters, dist = 0.000096
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000274, ||G - G0|| = 0.000000, dist = 0.000274
# 	Converged in 122 iters, dist = 0.000096
# G1 across pairs: (-0.01467029823812993, 0.011584004895629718)
# G1 vs G2 (η effect): (-0.4184526073252357, 0.01914573158027233)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.4184526073252357, 0.01914573158027233)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.007262381314532032
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.126368    0.937969    0.027931    1.0000      641
#    2→1         0.147267    0.934053    0.005296    1.0000      135
#    1→2         0.124254    0.938358    0.029586    1.0000      135
#    2→2         0.149072    0.933756    0.002490    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer 19 | foredist = 0.020301
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.6855, 9.7458
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.7099     0.0136     9.6892     9.7076     9.7452
#    2→1          135     9.6945     0.0109     9.6855     9.6898     9.7318
#    1→2          135     9.7118     0.0136     9.6892     9.7102     9.7458
#    2→2         3589     9.6947     0.0098     9.6855     9.6912     9.7430
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.6974     0.0121     9.6855     9.6933     9.7458
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000124, ||G - G0|| = 0.000000, dist = 0.000124
# 	Converged in 106 iters, dist = 0.000098
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000281, ||G - G0|| = 0.000000, dist = 0.000281
# 	Converged in 122 iters, dist = 0.000097
# G1 across pairs: (-0.029781674567786354, 0.0227305165883096)
# G1 vs G2 (η effect): (-0.4151048688072052, 0.020496499563858794)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.4151048688072052, 0.020496499563858794)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed: true
# Max abs change: 0.00721331493296733
#
# Forecast rules:  log K' = a + b·log K
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z                a           b        c(Θ)        R²        n
# ────────────────────────────────────────────────────────────────────────
#    1→1         0.151993    0.933069    0.002547    1.0000      641
#    2→1         0.151569    0.932978    0.003330    1.0000      135
#    1→2         0.149914    0.933509    0.003271    1.0000      135
#    2→2         0.151325    0.933213    0.001373    1.0000     3589
# ──────────────────────────────────────────────────────────────
# Outer 20 | foredist = 0.011919
# K range for (0.00, 0.00) vs (0.08, 0.00): 9.7453, 9.8645
#
# Kt summary by transition (post burn-in)
# ────────────────────────────────────────────────────────────────────────
#   z₋₁→z           n       mean        std        min     median        max
# ────────────────────────────────────────────────────────────────────────
#    1→1          641     9.7937     0.0268     9.7526     9.7891     9.8633
#    2→1          135     9.7630     0.0214     9.7453     9.7538     9.8366
#    1→2          135     9.7973     0.0268     9.7527     9.7943     9.8645
#    2→2         3589     9.7634     0.0192     9.7453     9.7566     9.8588
# ────────────────────────────────────────────────────────────────────────
#   ALL          4500     9.7688     0.0239     9.7453     9.7606     9.8645
# ────────────────────────────────────────────────────────────────────────
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000118, ||G - G0|| = 0.000000, dist = 0.000118
# 	Converged in 105 iters, dist = 0.000097
# Solving Household Problem...
# 	Iteration 100: ||V - V0|| = 0.000278, ||G - G0|| = 0.000000, dist = 0.000278
# 	Converged in 122 iters, dist = 0.000097
# G1 across pairs: (-0.0202146131723282, 0.01571044794760157)
# G1 vs G2 (η effect): (-0.41673153304924426, 0.01976995570101936)
# G1 === G2: false
# prices1.r === prices2.r: false
# G1 vs G2 extrema: (-0.41673153304924426, 0.01976995570101936)
# 	Simulating period 2500 of 5000
# 	Simulating period 5000 of 5000
# Distribution changed:
# InterruptException:
#
# Stacktrace:
#   [1] try_yieldto(undo::typeof(Base.ensure_rescheduled))
#     @ Base .\task.jl:1157
#   [2] wait()
#     @ Base .\task.jl:1229
#   [3] uv_write(s::Base.PipeEndpoint, p::Ptr{UInt8}, n::UInt64)
#     @ Base .\stream.jl:1081
#   [4] unsafe_write(s::Base.PipeEndpoint, p::Ptr{UInt8}, n::UInt64)
#     @ Base .\stream.jl:1154
#   [5] unsafe_write
#     @ .\io.jl:454 [inlined]
#   [6] write
#     @ .\strings\io.jl:246 [inlined]
#   [7] print
#     @ .\strings\io.jl:248 [inlined]
#   [8] print(::IJulia.IJuliaStdio{Base.PipeEndpoint}, ::String, ::Bool, ::String)
#     @ Base .\strings\io.jl:46
#   [9] println(x1::String, x2::Bool)
#     @ Base .\coreio.jl:6
#  [10] genForecastData(V::Array{…}, V0::Array{…}, G::Array{…}, G0::Array{…}, C::Array{…}, Kfore::Matrix{…}, params::ModelParams, policies1::ProposedPolicies, policies2::ProposedPolicies, prices1::ImpliedRegimeParams_KS, prices2::ImpliedRegimeParams_KS, zt::Vector{…}, vTol::Float64; verbose::Bool)
#     @ Main.Predict C:\VAASAVI\Dropbox\Education\OSU\Ongoing_Research\Populism\political-polarization\p\src\Predict.jl:115
#  [11] top-level scope
#     @ In[19]:7
#  [12] eval(m::Module, e::Any)
#     @ Core .\boot.jl:489
# Some type information was truncated. Use `show(err)` to see complete types.

# %%
# choose a random starting point for the simulation
ik0 = cld(nk, 2); K0 = Kgrid[ik0];
Kt = zeros(NT+1); Kt[1] = Kgrid[ik0]

# initial distribution: stationary at starting K, lifted to pair-state
G_start = G1[ik0, :, :, :]                        # (nt, nl,na) (base K)

# ... lift to pair-state (nz²) if getDistr is pair-state ...
μ_transit, _ = getDistr(G_start, params.amu, params.agrid, params.π_l, params.π_z,
                     CI, LI, params.ϕ)

#@printf("getDistr: sum(μ_transit) = %.10f  (want 1.0)\n", sum(μ_transit))
#@printf("          min = %.3e  (want ≥ 0, no negatives)\n", minimum(μ_transit))

#@printf("collapse: sum(μ_today) = %.10f  (want = sum(μ_prev))\n", sum(μ_transit))
med_ind = ceil(Int, median(1:length(params.zgrid)))
it_t = zeros(Int, NT);
it_t[1] = LI[med_ind, med_ind]   # initial pair-state index
it_t[2:NT] = [LI[zt[t-1], zt[t]] for t in 2:NT];
μ_transit = μ_transit[it_t[1], :, :]
votes_t = zeros(Float64, NT);
# Out:
# UndefVarError: `G1` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[9]:6
#  [2] eval(m::Module, e::Any)
#    @ Core .\boot.jl:489

# %%
for t in 1:NT
    if t%2500 == 0 && verbose
        @printf("\tSimulating period %i of %i\n", t, NT)
    end

    # getting today's vote to be used for tomorrow. 
    K = Kt[t]; ix, we = weight(Kgrid, K);
    it = it_t[t] # getting which z transition we're in
    VOTES_t = we.*VOTES[ix, it, :, :] + (1-we) .* VOTES[ix+1, it, :, :];
    _, voteshare = mapVotes(VOTES_t, params, μ_transit)
    votes_t[t] = voteshare;

    # update the distribution for the next period
    G_t = we .* G1[ix, it, :, :] .+ (1-we) .* G1[ix+1, it, :, :];   # (nl, na)
    mass_before = sum(μ_transit)
    μ_transit, Kt[t+1] = transitDistr(G_t, μ_transit, params.amu, params.agrid, params.ϕ, params.π_l)
    mass_after = sum(μ_transit)

    if abs(mass_after - mass_before) > 1e-8
        @printf("LEAK at t=%i: before=%.10f after=%.10f  Δ=%.3e  (K=%.4f)\n",
                t, mass_before, mass_after, mass_after - mass_before, K)
    end
end
# Out:
# UndefVarError: `VOTES` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ .\In[10]:10
#  [2] eval(m::Module, e::Any)
#    @ Core .\boot.jl:489

# %%
Kfore_new, R2, counts = update_forecast(Kt, it_t, votes_t, nt, burnin)
foredist = maximum(abs.(Kfore_new[:,1:2] .- Kfore[:,1:2]))

if verbose
    CI = CartesianIndices(params.π_z)
    println("\nForecast rules:  log K' = a + b·log K")
    println("─"^72)
    @printf("  %-10s %11s %11s %11s %9s %8s\n", "z₋₁→z", "a", "b", "c(Θ)", "R²", "n")
    println("─"^72)
    for z1z2 in 1:nt
        zprev, znow = CI[z1z2][1], CI[z1z2][2]
        flag = (isnan(R2[z1z2]) || R2[z1z2] < 0.99) ? "  ⚠" : ""
        @printf("  %2d→%-6d %11.6f %11.6f %11.6f %9.4f %8d%s\n",
            zprev, znow, Kfore_new[z1z2,1], Kfore_new[z1z2,2],
            Kfore_new[z1z2, 3], R2[z1z2], counts[z1z2], flag)
    end
    println("─"^62)
    @printf("Outer %2i | foredist = %.6f\n", outer_ct, foredist)
    @printf("K range for (%4.2f, %4.2f) vs (%4.2f, %4.2f): %2.4f, %2.4f\n",
        policies1.η, policies1.τ, policies2.η, policies2.τ,
        minimum(Kt[501:end]), maximum(Kt[501:end]))

    summarizeKtByTransition(Kt, it_t, params.π_z, burnin)
    summarizeKtByTransition(votes_t, it_t, params.π_z, burnin)
    
    @printf("Vote share extrema: %0.6f, %0.6f\n", extrema(votes_t)...)
end

extrema(votes_t[2:end])
# damped update
# Kfore = λ_damp .* Kfore_new .+ (1 - λ_damp) .* Kfore
# outer_ct += 1

println(length(findall(votes_t .> 0)))        # how many nonzero periods total
println(minimum(findall(votes_t .> 0)))       # earliest period with a vote
println(maximum(findall(votes_t .> 0)))       # latest
println(count(findall(votes_t .> 0) .> 500))  # how many are POST burn-in

println(mean(votes_t))
println(median(votes_t))

println(argmax(votes_t))   # which period has the 0.0097
println(it_t[argmax(votes_t)])  # what pair is it assigned to
# Out:
# SingularException(2)
#
# Stacktrace:
#   [1] chknonsingular
#     @ C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\lapack.jl:48 [inlined]
#   [2] chklapackerror_positive
#     @ C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\lapack.jl:3638 [inlined]
#   [3] chklapackerror
#     @ C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\lapack.jl:40 [inlined]
#   [4] trtrs!(uplo::Char, trans::Char, diag::Char, A::SubArray{…}, B::SubArray{…})
#     @ LinearAlgebra.LAPACK C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\lapack.jl:3633
#   [5] generic_trimatdiv!
#     @ C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\triangular.jl:1273 [inlined]
#   [6] _ldiv!
#     @ C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\triangular.jl:1171 [inlined]
#   [7] ldiv!
#     @ C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\triangular.jl:1178 [inlined]
#   [8] ldiv!(A::QRPivoted{Float64, Matrix{Float64}, Vector{Float64}, Vector{Int64}}, B::Matrix{Float64}, rcond::Float64)
#     @ LinearAlgebra C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\qr.jl:627
#   [9] ldiv!
#     @ C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\qr.jl:649 [inlined]
#  [10] ldiv!
#     @ C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\qr.jl:647 [inlined]
#  [11] ldiv(F::QRPivoted{Float64, Matrix{Float64}, Vector{Float64}, Vector{Int64}}, B::Vector{Float64})
#     @ LinearAlgebra C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\LinearAlgebra.jl:715
#  [12] \
#     @ C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\LinearAlgebra.jl:690 [inlined]
#  [13] \(A::Matrix{Float64}, B::Vector{Float64})
#     @ LinearAlgebra C:\Users\unnav\.julia\juliaup\julia-1.12.6+0.x64.w64.mingw32\share\julia\stdlib\v1.12\LinearAlgebra\src\generic.jl:1236
#  [14] update_forecast(Kt::Vector{Float64}, it_t::Vector{Int64}, votes_t::Vector{Float64}, nt::Int64, burn_in::Int64)
#     @ Main.Predict C:\VAASAVI\Dropbox\Education\OSU\Ongoing_Research\Populism\political-polarization\p\src\Predict.jl:141
#  [15] top-level scope
#     @ In[11]:1
#  [16] eval(m::Module, e::Any)
#     @ Core .\boot.jl:489
# Some type information was truncated. Use `show(err)` to see complete types.

# %%
println(sum(VOTES == 0))

println(all(V1 .> V2))    # true if V1 strictly dominates everywhere
println(all(V2 .> V1))    # true if V2 strictly dominates everywhere
println(count(V1 .> V2))  # how many states V1 wins
println(count(V2 .> V1))  # how many states V2 wins

println(count(EV1 .> EV2))   # this is what determines VOTES
println(count(EV2 .> EV1))
println(extrema(EV1 .- EV2)) # how big is the gap, and what sign?

println("Extrema of V1")
println(extrema(V1))

println(extrema(prices1.r .- prices2.r))
println(extrema(prices1.w .- prices2.w))
println(extrema(prices1.λ .- prices2.λ))

println(extrema(G1))

# initial distribution: stationary at starting K, lifted to pair-state
G_start = G1[cld(nk, 2), :, :, :]                        # (nt, nl,na) (base K)

# ... lift to pair-state (nz²) if getDistr is pair-state ...
μ_transit, Kagg = getDistr(G_start, params.amu, params.agrid, params.π_l, params.π_z,
                     CI, LI, params.ϕ);
println(Kagg)
println(size(μ_transit))

println(V1 === V2)
# Out:
# UndefVarError: `VOTES` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[12]:2
#  [2] eval(m::Module, e::Any)
#    @ Core .\boot.jl:489

# %%
# choose a random starting point for the simulation
NT = length(zt);
ik0 = cld(nk, 2); K0 = Kgrid[ik0];
Kt = zeros(NT+1); Kt[1] = Kgrid[ik0]

# initial distribution: stationary at starting K, lifted to pair-state
G_start = G1[ik0, :, :, :]                        # (nt, nl,na) (base K)

# ... lift to pair-state (nz²) if getDistr is pair-state ...
μ_transit, _ = getDistr(G_start, params.amu, params.agrid, params.π_l, params.π_z,
                     CI, LI, params.ϕ)

#@printf("getDistr: sum(μ_prev) = %.10f  (want 1.0)\n", sum(μ_prev))
#@printf("          min = %.3e  (want ≥ 0, no negatives)\n", minimum(μ_prev))

#@printf("collapse: sum(μ_today) = %.10f  (want = sum(μ_prev))\n", sum(μ_today))
med_ind = ceil(Int, median(1:length(params.zgrid)))
it_t = zeros(Int, NT);
it_t[1] = LI[med_ind, med_ind]   # initial pair-state index
it_t[2:NT] = [LI[zt[t-1], zt[t]] for t in 2:NT];
μ_transit = μ_transit[it_t[1], :, :]
votes_t = zeros(Float64, NT);

for t in 1:NT
    if t%2500 == 0 && verbose
        @printf("\tSimulating period %i of %i\n", t, NT)
    end

    # getting today's vote to be used for tomorrow. 
    K = Kt[t]; ix, we = weight(Kgrid, K);
    it = it_t[t] # getting which z transition we're in
    VOTES_t = we.*VOTES[ix, it, :, :] + (1-we) .* VOTES[ix+1, it, :, :];
    _, voteshare = mapVotes(VOTES_t, params, μ_transit)
    votes_t[t] = voteshare;

    # update the distribution for the next period
    G_t = we .* G[ix, it, :, :] .+ (1-we) .* G[ix+1, it, :, :];   # (nl, na)
    mass_before = sum(μ_transit)
    μ_transit, Kt[t+1] = transitDistr(G_t, μ_transit, params.amu, params.agrid, params.ϕ, params.π_l)
    mass_after = sum(μ_transit)

    if abs(mass_after - mass_before) > 1e-8
        @printf("LEAK at t=%i: before=%.10f after=%.10f  Δ=%.3e  (K=%.4f)\n",
                t, mass_before, mass_after, mass_after - mass_before, K)
    end
end

Kfore_new, R2, counts = update_forecast(Kt, it_t, votes_t, nt, burnin)
foredist = maximum(abs.(Kfore_new[:,1:2] .- Kfore[:,1:2]))

if verbose
    CI = CartesianIndices(params.π_z)
    println("\nForecast rules:  log K' = a + b·log K")
    println("─"^72)
    @printf("  %-10s %11s %11s %11s %9s %8s\n", "z₋₁→z", "a", "b", "c(Θ)", "R²", "n")
    println("─"^72)
    for z1z2 in 1:nt
        zprev, znow = CI[z1z2][1], CI[z1z2][2]
        flag = (isnan(R2[z1z2]) || R2[z1z2] < 0.99) ? "  ⚠" : ""
        @printf("  %2d→%-6d %11.6f %11.6f %11.6f %9.4f %8d%s\n",
            zprev, znow, Kfore_new[z1z2,1], Kfore_new[z1z2,2],
            Kfore_new[z1z2, 3], R2[z1z2], counts[z1z2], flag)
    end
    println("─"^62)
    @printf("Outer %2i | foredist = %.6f\n", outer_ct, foredist)
    @printf("K range for (%4.2f, %4.2f) vs (%4.2f, %4.2f): %2.4f, %2.4f\n",
        policies1.η, policies1.τ, policies2.η, policies2.τ,
        minimum(Kt[501:end]), maximum(Kt[501:end]))

    summarizeKtByTransition(Kt, it_t, params.π_z, burnin)
end

# damped update
Kfore = λ_damp .* Kfore_new .+ (1 - λ_damp) .* Kfore
outer_ct += 1
# Out:
# invalid assignment to constant Main.NT. This redefinition may be permitted using the `const` keyword.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[13]:3
#  [2] eval(m::Module, e::Any)
#    @ Core .\boot.jl:489
